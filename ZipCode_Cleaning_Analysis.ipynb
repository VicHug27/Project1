# %%
#import dependencies
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.ticker as mticker
#import numpy as np
import requests
import datetime
from scipy.stats import linregress
import matplotlib.ticker as mtick

# %%
#import the cleaned mls data

#file path
file = "DataCleaning/CleanedMLSData.csv"

#read the file into pandas and view info
mls_df = pd.read_csv(file, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
mls_df.head()
# Out:
#       MLS # Status                Address        City Zip Code List Price  \
# 0  14112331      S     452 Vincent Street  Cedar Hill    75104    95000.0
# 1  14075152      S  914 S Cedar Hill Road  Cedar Hill    75104   119000.0
# 2  14088584      S      1015 Vedral Place  Cedar Hill    75104   110000.0
# 3  14086347      S     309 Aquarius Drive  Cedar Hill    75104   129900.0
# 4  14094254      S      1114 Saturn Drive  Cedar Hill    75104   119900.0
#
#   Original List Price SqFt Total Close Price RATIO Current Price By SQFT  ...  \
# 0             95000.0     1310.0    109300.0                       83.44  ...
# 1            119000.0     1260.0    111268.0                       88.31  ...
# 2            110000.0     1002.0    112000.0                      111.78  ...
# 3            129900.0     1085.0    120000.0                       110.6  ...
# 4            119900.0     1031.0    120000.0                      116.39  ...
#
#   Status Change Timestamp List Agent Full Name Buyers/SubAgent Full Name  \
# 0              2019-07-04       Krista Stotler           Cassandra Jones
# 1              2019-06-06     Leslie Armstrong              Carlos Silva
# 2              2019-06-03      Richard Garropy            Mayra Cardenas
# 3              2019-06-24         Dianna Jones              Dianna Jones
# 4              2019-06-25          Gail Griggs             Angela Hudson
#
#          HOA      MLS SubArea  Property Sub Type Property Type  \
# 0       None  CEDAR HILL (10)  RES-Single Family   Residential
# 1       None  CEDAR HILL (13)  RES-Single Family   Residential
# 2  Mandatory   CEDAR HILL (3)          RES-Condo   Residential
# 3       None  CEDAR HILL (13)  RES-Single Family   Residential
# 4       None  CEDAR HILL (13)  RES-Single Family   Residential
#
#   RATIO Close Price By List Price School District          Subdivision Name
# 0              1.1505299999999998  Cedar Hill ISD  Highlands 03 & 08 02 Rep
# 1              0.9350299999999999  Cedar Hill ISD                Cedar Hill
# 2              1.0181799999999999  Cedar Hill ISD              Cedars Condo
# 3                         0.92379  Cedar Hill ISD       South Hills Park 01
# 4              1.0008299999999999  Cedar Hill ISD       South Hills Park 01
#
# [5 rows x 32 columns]

# %%
#convert all number data types to float or integer
mls_df[["MLS #"]] = mls_df[["MLS #"]].apply(pd.to_numeric)
mls_df[["List Price"]] = mls_df[["List Price"]].astype(float)
mls_df[["Original List Price"]] = mls_df[["Original List Price"]].astype(float)

mls_df[["SqFt Total", "Close Price", "Number Of Stories", "RATIO Current Price By SQFT", 
        "Beds Total", "Baths Total", "Parking Spaces Garage", "Lot Size Area", "DOM", 
        "RATIO Close Price By List Price", "Zip Code"]] \
= mls_df[["SqFt Total", "Close Price", "Number Of Stories", "RATIO Current Price By SQFT", 
          "Beds Total", "Baths Total", "Parking Spaces Garage", "Lot Size Area", "DOM", 
          "RATIO Close Price By List Price", "Zip Code"]].apply(pd.to_numeric)

mls_df[["Yr Built"]] = mls_df[["Yr Built"]].astype(float)

#convert all dates to date
mls_df[["Listing Date"]] = pd.to_datetime(mls_df["Listing Date"], format='%Y-%m-%d')
mls_df[["Close Date"]] = pd.to_datetime(mls_df["Close Date"], format='%Y-%m-%d')
mls_df[["Expiration Date"]] = pd.to_datetime(mls_df["Expiration Date"], format='%Y-%m-%d')
mls_df[["Cancelled Date"]] = pd.to_datetime(mls_df["Cancelled Date"], format='%Y-%m-%d')
mls_df[["Status Change Timestamp"]] = pd.to_datetime(mls_df["Status Change Timestamp"], format='%Y-%m-%d')

#convert all strings from objects to string

mls_df[['Status', 'Address', 'City', 'List Agent Full Name', 'Buyers/SubAgent Full Name', 
        'MLS SubArea', 'Property Sub Type', 'Property Type', 'School District', 'Subdivision Name', 'HOA', 'Pool']] \
= mls_df[['Status', 'Address', 'City', 'List Agent Full Name', 'Buyers/SubAgent Full Name', 
        'MLS SubArea', 'Property Sub Type', 'Property Type', 'School District', 'Subdivision Name', 'HOA', 'Pool']].convert_dtypes()
    
mls_df['Status'] = mls_df['Status'].convert_dtypes()

mls_df.dtypes
# Out:
# MLS #                                       int64
# Status                                     string
# Address                                    string
# City                                       string
# Zip Code                                    int64
# List Price                                float64
# Original List Price                       float64
# SqFt Total                                float64
# Close Price                               float64
# RATIO Current Price By SQFT               float64
# Number Of Stories                         float64
# Beds Total                                  int64
# Baths Total                               float64
# Parking Spaces Garage                     float64
# Lot Size Area                             float64
# Yr Built                                  float64
# Pool                                       string
# DOM                                         int64
# Listing Date                       datetime64[ns]
# Close Date                         datetime64[ns]
# Expiration Date                    datetime64[ns]
# Cancelled Date                     datetime64[ns]
# Status Change Timestamp            datetime64[ns]
# List Agent Full Name                       string
# Buyers/SubAgent Full Name                  string
# HOA                                        string
# MLS SubArea                                string
# Property Sub Type                          string
# Property Type                              string
# RATIO Close Price By List Price           float64
# School District                            string
# Subdivision Name                           string
# dtype: object

# %%
#get list of column values
#df.columns.values.tolist()

# %%
#create new DataFrame of only sold (S) properties and narrow the columns
columns = ['MLS #','Status','Address','City','List Price',
           'Original List Price','SqFt Total','Close Price',
           'RATIO Current Price By SQFT','Number Of Stories','Beds Total',
           'Baths Total','Parking Spaces Garage','Lot Size Area','Yr Built',
            'Pool','DOM','Listing Date','Close Date', 'List Agent Full Name',
            'Buyers/SubAgent Full Name', 'RATIO Close Price By List Price',
            'School District', 'Subdivision Name','Zip Code', "Property Sub Type", "Property Type"]

sold_mls_df = mls_df.loc[mls_df["Status"] == "S", columns]

sold_mls_df["Status"].unique()
# Out:
# <StringArray>
# ['S']
# Length: 1, dtype: string

# %%
sold_mls_df.dtypes
# Out:
# MLS #                                       int64
# Status                                     string
# Address                                    string
# City                                       string
# List Price                                float64
# Original List Price                       float64
# SqFt Total                                float64
# Close Price                               float64
# RATIO Current Price By SQFT               float64
# Number Of Stories                         float64
# Beds Total                                  int64
# Baths Total                               float64
# Parking Spaces Garage                     float64
# Lot Size Area                             float64
# Yr Built                                  float64
# Pool                                       string
# DOM                                         int64
# Listing Date                       datetime64[ns]
# Close Date                         datetime64[ns]
# List Agent Full Name                       string
# Buyers/SubAgent Full Name                  string
# RATIO Close Price By List Price           float64
# School District                            string
# Subdivision Name                           string
# Zip Code                                    int64
# Property Sub Type                          string
# Property Type                              string
# dtype: object

# %%
sold_mls_df.head()
# Out:
#       MLS # Status                Address        City  List Price  \
# 0  14112331      S     452 Vincent Street  Cedar Hill     95000.0
# 1  14075152      S  914 S Cedar Hill Road  Cedar Hill    119000.0
# 2  14088584      S      1015 Vedral Place  Cedar Hill    110000.0
# 3  14086347      S     309 Aquarius Drive  Cedar Hill    129900.0
# 4  14094254      S      1114 Saturn Drive  Cedar Hill    119900.0
#
#    Original List Price  SqFt Total  Close Price  RATIO Current Price By SQFT  \
# 0              95000.0      1310.0     109300.0                        83.44
# 1             119000.0      1260.0     111268.0                        88.31
# 2             110000.0      1002.0     112000.0                       111.78
# 3             129900.0      1085.0     120000.0                       110.60
# 4             119900.0      1031.0     120000.0                       116.39
#
#    Number Of Stories  ...  Listing Date  Close Date  List Agent Full Name  \
# 0                1.0  ...    2019-06-09  2019-06-25        Krista Stotler
# 1                1.0  ...    2019-05-02  2019-06-04      Leslie Armstrong
# 2                2.0  ...    2019-05-11  2019-05-31       Richard Garropy
# 3                1.0  ...    2019-05-11  2019-06-21          Dianna Jones
# 4                1.0  ...    2019-05-19  2019-06-04           Gail Griggs
#
#    Buyers/SubAgent Full Name  RATIO Close Price By List Price School District  \
# 0            Cassandra Jones                          1.15053  Cedar Hill ISD
# 1               Carlos Silva                          0.93503  Cedar Hill ISD
# 2             Mayra Cardenas                          1.01818  Cedar Hill ISD
# 3               Dianna Jones                          0.92379  Cedar Hill ISD
# 4              Angela Hudson                          1.00083  Cedar Hill ISD
#
#            Subdivision Name Zip Code  Property Sub Type Property Type
# 0  Highlands 03 & 08 02 Rep    75104  RES-Single Family   Residential
# 1                Cedar Hill    75104  RES-Single Family   Residential
# 2              Cedars Condo    75104          RES-Condo   Residential
# 3       South Hills Park 01    75104  RES-Single Family   Residential
# 4       South Hills Park 01    75104  RES-Single Family   Residential
#
# [5 rows x 27 columns]

# %%
#count how many sales per zipcode

zipcode_counts = sold_mls_df["Zip Code"].value_counts()
zipcode_counts
# Out:
# 75043    3918
# 75206    3659
# 75214    3545
# 75115    3498
# 75219    3399
#          ...
# 75067      64
# 75151      30
# 75226      22
# 75287      18
# 75125       1
# Name: Zip Code, Length: 89, dtype: int64

# %%
#get counts of unique zipcodes
zipcode_counts_df = pd.DataFrame(zipcode_counts)

zipcode_counts_df
# Out:
#        Zip Code
# 75043      3918
# 75206      3659
# 75214      3545
# 75115      3498
# 75219      3399
# ...         ...
# 75067        64
# 75151        30
# 75226        22
# 75287        18
# 75125         1
#
# [89 rows x 1 columns]

# %%
#export as csv to sort ascending and manually check against combinedmlsdata.csv. 
#Look up the outliers and change in combinedmlsdata.csv and save.
##zip_csv_data = zipcode_counts_df.to_csv("ZipMLSData.csv", index=True, encoding='utf-8')

# %%
sold_mls_df.dtypes
# Out:
# MLS #                                       int64
# Status                                     string
# Address                                    string
# City                                       string
# List Price                                float64
# Original List Price                       float64
# SqFt Total                                float64
# Close Price                               float64
# RATIO Current Price By SQFT               float64
# Number Of Stories                         float64
# Beds Total                                  int64
# Baths Total                               float64
# Parking Spaces Garage                     float64
# Lot Size Area                             float64
# Yr Built                                  float64
# Pool                                       string
# DOM                                         int64
# Listing Date                       datetime64[ns]
# Close Date                         datetime64[ns]
# List Agent Full Name                       string
# Buyers/SubAgent Full Name                  string
# RATIO Close Price By List Price           float64
# School District                            string
# Subdivision Name                           string
# Zip Code                                    int64
# Property Sub Type                          string
# Property Type                              string
# dtype: object

# %% [markdown]
# ## Zipcode Analysis
#
# #### - Run calculations to obtain statistics for Zipcodes
# #### - Create summary data frame to hold results

# %%
sold_mls_df[["Close Price"]] = sold_mls_df[["Close Price"]].astype(float)

ZipcodeAnalysis = sold_mls_df.groupby(["Zip Code"])

ZipCount = ZipcodeAnalysis["MLS #"].count()
AveragePrice = ZipcodeAnalysis["Close Price"].mean()
MedianPrice = ZipcodeAnalysis["Close Price"].median()
MinPrice = ZipcodeAnalysis["Close Price"].min()
MaxPrice = ZipcodeAnalysis["Close Price"].max()
AverageDOM = ZipcodeAnalysis["DOM"].mean()


ZipcodeAnalysis_df = pd.DataFrame({"Sale Count": ZipCount,
                                   "Average Days on Market": AverageDOM,
                                   "Average Sale Price": AveragePrice,
                                   "Median Sale Price": MedianPrice,
                                   "Min Sale Price": MinPrice, 
                                   "Max Sale Price": MaxPrice,})

#sort by average sale price
ZipcodeAnalysis_df = ZipcodeAnalysis_df.sort_values("Average Sale Price", ascending=False)

#convert data types
#ZipcodeAnalysis_df[["Average Sale Price"]] = ZipcodeAnalysis_df[["Average Sale Price"]].apply(pd.to_numeric)
#ZipcodeAnalysis_df["Average Sale Price"].astype(float)
#ZipcodeAnalysis_df["Average Sale Price"].astype(float)
#ZipcodeAnalysis_df["Average Sale Price"].astype(float)

#formatting
#ZipcodeAnalysis_df["Average Sale Price"] = ZipcodeAnalysis_df["Average Sale Price"].map("${:,.2f}".format)
#ZipcodeAnalysis_df["Median Sale Price"] = ZipcodeAnalysis_df["Median Sale Price"].map("${:,.2f}".format)
#ZipcodeAnalysis_df["Min Sale Price"] = ZipcodeAnalysis_df["Min Sale Price"].map("${:,.2f}".format)
#ZipcodeAnalysis_df["Max Sale Price"] = ZipcodeAnalysis_df["Max Sale Price"].map("${:,.2f}".format)

# %% [markdown]
# ### Obtain top 5 and bottom 5 Zipcodes based on Average Sale Price for Zip Codes with more than 500 sales
# #### Top 5: 75205, 75225, 75201, 75209, 75230
# #### Bottom 5: 75149, 75180, 75241, 75217

# %%
SalesZipCodeAnalysis_df = ZipcodeAnalysis_df[(ZipcodeAnalysis_df["Sale Count"]>500)]

SalesZipCodeAnalysis_df.head()
# Out:
#           Sale Count  Average Days on Market  Average Sale Price  \
# Zip Code
# 75205           2027               68.802171        1.481433e+06
# 75225           2089               67.202011        1.320437e+06
# 75201            515               90.532039        1.012337e+06
# 75209           1905               64.281365        8.148907e+05
# 75230           2974               60.650975        7.962716e+05
#
#           Median Sale Price  Min Sale Price  Max Sale Price
# Zip Code
# 75205             1150000.0         99500.0      21500000.0
# 75225             1199000.0         95000.0      18500000.0
# 75201              695000.0        169000.0       7000000.0
# 75209              649000.0         28900.0       8400000.0
# 75230              644500.0         49000.0       6500000.0

# %%
#view bottom 5 zipcodes with lowest sale price.

SalesZipCodeAnalysis_df.tail()
# Out:
#           Sale Count  Average Days on Market  Average Sale Price  \
# Zip Code
# 75149           3346               24.300658       160165.484160
# 75180            904               24.619469       157160.275442
# 75241           1447               29.807187       137271.304768
# 75217           2038               30.234544       136955.379293
# 75216           1905               36.127034       135694.144882
#
#           Median Sale Price  Min Sale Price  Max Sale Price
# Zip Code
# 75149              160000.0         36000.0        660000.0
# 75180              155000.0         32000.0        570000.0
# 75241              140000.0            10.0        766500.0
# 75217              138000.0           110.0        932500.0
# 75216              135400.0         13000.0        449900.0

# %% [markdown]
# # Sale Count by Sale Price

# %%
Bins = [0, 99999 , 249999, 499999, 749999, 999999, 1999999, 3999999, 999999999999]
Labels = ["< $100k", "$100k - $250k", "$250k - $500k", "$500k - $750k", "$750k - $1mil", "$1mil - $2mil", "$2mil -$ 4mil", "$4mil+"]

pd.cut(sold_mls_df["Close Price"], Bins, labels=Labels)

sold_mls_df["Price Group"] = pd.cut(sold_mls_df["Close Price"], Bins, labels=Labels)

PriceGroup = sold_mls_df.groupby("Price Group")

SaleCount = PriceGroup["MLS #"].count()
AveragePrice = PriceGroup["Close Price"].mean()
MedianPrice = PriceGroup["Close Price"].median()
MinPrice = PriceGroup["Close Price"].min()
MaxPrice = PriceGroup["Close Price"].max()
AverageDOM = PriceGroup["DOM"].mean()


PriceGroup_df = pd.DataFrame({"Sale Count": SaleCount,
                                   "Average Days on Market": AverageDOM,
                                   "Average Sale Price": AveragePrice,
                                   "Median Sale Price": MedianPrice,
                                   "Min Sale Price": MinPrice, 
                                   "Max Sale Price": MaxPrice,})

PriceGroup_df
# Out:
#                Sale Count  Average Days on Market  Average Sale Price  \
# Price Group
# < $100k              6627               31.118606        7.336644e+04
# $100k - $250k       61697               27.003631        1.799900e+05
# $250k - $500k       44390               42.084659        3.464341e+05
# $500k - $750k       11001               55.436869        5.957310e+05
# $750k - $1mil        3666               59.530551        8.569254e+05
# $1mil - $2mil        4459               70.105181        1.378838e+06
# $2mil -$ 4mil        1194               98.041039        2.621676e+06
# $4mil+                211              156.739336        6.072677e+06
#
#                Median Sale Price  Min Sale Price  Max Sale Price
# Price Group
# < $100k                  76560.0            10.0         99999.0
# $100k - $250k           180000.0        100000.0        249999.0
# $250k - $500k           335000.0        250000.0        499999.0
# $500k - $750k           583000.0        500000.0        749999.0
# $750k - $1mil           850000.0        750000.0        999999.0
# $1mil - $2mil          1325000.0       1000000.0       1999000.0
# $2mil -$ 4mil          2500000.0       2000000.0       3995000.0
# $4mil+                 5200000.0       4000000.0      39200000.0

# %%
import seaborn as sns
#Generate a bar graph showing the distribution of total sales in each price group

sns.displot(sold_mls_df["Price Group"], binwidth=50, discrete=True)
plt.xticks(rotation=45)
plt.show()

# %%
sold_mls_df.head()
# Out:
#       MLS # Status                Address        City  List Price  \
# 0  14112331      S     452 Vincent Street  Cedar Hill     95000.0
# 1  14075152      S  914 S Cedar Hill Road  Cedar Hill    119000.0
# 2  14088584      S      1015 Vedral Place  Cedar Hill    110000.0
# 3  14086347      S     309 Aquarius Drive  Cedar Hill    129900.0
# 4  14094254      S      1114 Saturn Drive  Cedar Hill    119900.0
#
#    Original List Price  SqFt Total  Close Price  RATIO Current Price By SQFT  \
# 0              95000.0      1310.0     109300.0                        83.44
# 1             119000.0      1260.0     111268.0                        88.31
# 2             110000.0      1002.0     112000.0                       111.78
# 3             129900.0      1085.0     120000.0                       110.60
# 4             119900.0      1031.0     120000.0                       116.39
#
#    Number Of Stories  ...  Close Date  List Agent Full Name  \
# 0                1.0  ...  2019-06-25        Krista Stotler
# 1                1.0  ...  2019-06-04      Leslie Armstrong
# 2                2.0  ...  2019-05-31       Richard Garropy
# 3                1.0  ...  2019-06-21          Dianna Jones
# 4                1.0  ...  2019-06-04           Gail Griggs
#
#    Buyers/SubAgent Full Name  RATIO Close Price By List Price  \
# 0            Cassandra Jones                          1.15053
# 1               Carlos Silva                          0.93503
# 2             Mayra Cardenas                          1.01818
# 3               Dianna Jones                          0.92379
# 4              Angela Hudson                          1.00083
#
#    School District          Subdivision Name  Zip Code  Property Sub Type  \
# 0   Cedar Hill ISD  Highlands 03 & 08 02 Rep     75104  RES-Single Family
# 1   Cedar Hill ISD                Cedar Hill     75104  RES-Single Family
# 2   Cedar Hill ISD              Cedars Condo     75104          RES-Condo
# 3   Cedar Hill ISD       South Hills Park 01     75104  RES-Single Family
# 4   Cedar Hill ISD       South Hills Park 01     75104  RES-Single Family
#
#   Property Type    Price Group
# 0   Residential  $100k - $250k
# 1   Residential  $100k - $250k
# 2   Residential  $100k - $250k
# 3   Residential  $100k - $250k
# 4   Residential  $100k - $250k
#
# [5 rows x 28 columns]

# %%
sold_mls_df["Close Year"] = sold_mls_df["Close Date"].dt.year
sold_mls_df["Close Month"] = pd.DatetimeIndex(sold_mls_df["Close Date"]).month

# %%
sold_mls_df['Close Date'].dt.year.nunique()
# Out:
# 6

# %%
DateGrouped = sold_mls_df.groupby(["Close Year"])
DateGrouped.groups.keys()
# Out:
# dict_keys([2016, 2017, 2018, 2019, 2020, 2021])

# %%
DateGrouped["Close Price"].describe()
# Out:
#               count           mean            std    min       25%       50%  \
# Close Year
# 2016        24362.0  308892.754659  366196.372475   10.0  140500.0  207000.0
# 2017        25796.0  337910.763529  389960.992970  149.0  162000.0  230000.0
# 2018        24604.0  353531.280320  501008.476015  110.0  174900.0  240000.0
# 2019        25201.0  355835.642197  393815.343296  205.0  184000.0  247000.0
# 2020        26279.0  388557.820465  442660.500760  875.0  199900.0  270000.0
# 2021         7003.0  443472.331429  584980.624954  315.0  219525.0  300000.0
#
#                  75%         max
# Close Year
# 2016        350000.0   9800000.0
# 2017        375000.0  10350000.0
# 2018        384992.5  39200000.0
# 2019        385000.0   8580000.0
# 2020        417500.0  14750000.0
# 2021        460500.0  21500000.0

# %% [markdown]
# # Graph Zip Codes

# %%
Mean75205 = sold_mls_df[sold_mls_df["Zip Code"] == 75205 ].groupby(["Close Year"])["Close Price"].mean()
Mean75225 = sold_mls_df[sold_mls_df["Zip Code"] == 75225 ].groupby(["Close Year"])["Close Price"].mean()
Mean75201 = sold_mls_df[sold_mls_df["Zip Code"] == 75201 ].groupby(["Close Year"])["Close Price"].mean()


sns.lineplot(data=Mean75205)
sns.lineplot(data=Mean75201)
sns.lineplot(data=Mean75225)
plt.show()

# %%
Mean75149 = sold_mls_df[sold_mls_df["Zip Code"] == 75149 ].groupby(["Close Year"])["Close Price"].mean()
Mean75180 = sold_mls_df[sold_mls_df["Zip Code"] == 75180 ].groupby(["Close Year"])["Close Price"].mean()
Mean75241 = sold_mls_df[sold_mls_df["Zip Code"] == 75241 ].groupby(["Close Year"])["Close Price"].mean()

sns.lineplot(data=Mean75149)
sns.lineplot(data=Mean75180)
sns.lineplot(data=Mean75241)
plt.show()

# %%
Top_Zip_df = sold_mls_df.loc[sold_mls_df["Zip Code"].isin([75205,75225,75201,75209,75230])]

Top_Zip_df.head()
# Out:
#          MLS # Status                          Address    City  List Price  \
# 1151  14013494      S    12888 Montfort Drive Unit#206  Dallas     87900.0
# 1154  14078620      S         7832 Royal Lane Unit#215  Dallas    110000.0
# 1156  14082466      S         7916 Royal Lane Unit#113  Dallas    129000.0
# 1157  14097765      S    12888 Montfort Drive Unit#109  Dallas    115000.0
# 1158  14104069      S  7814 Meadow Park Drive Unit#119  Dallas    112000.0
#
#       Original List Price  SqFt Total  Close Price  \
# 1151              89900.0       942.0      81000.0
# 1154             110000.0       786.0      95000.0
# 1156             139000.0      1110.0     100000.0
# 1157             115000.0       919.0     107500.0
# 1158             112000.0       755.0     112000.0
#
#       RATIO Current Price By SQFT  Number Of Stories  ...  \
# 1151                        85.99                1.0  ...
# 1154                       120.87                1.0  ...
# 1156                        90.09                2.0  ...
# 1157                       116.97                1.0  ...
# 1158                       148.34                1.0  ...
#
#       Buyers/SubAgent Full Name  RATIO Close Price By List Price  \
# 1151          Michael Mccasland                          0.92150
# 1154                 Jose Garza                          0.86364
# 1156               John Saldana                          0.77519
# 1157                  Raul Ruiz                          0.93478
# 1158                  Jeff Neal                          1.00000
#
#       School District              Subdivision Name  Zip Code  \
# 1151       Dallas ISD  Valley View Condo Ph 01 & 02     75230
# 1154       Dallas ISD             Royal Oaks Condos     75230
# 1156       Dallas ISD    Royal Central Condominiums     75230
# 1157       Dallas ISD  Valley View Condo Ph 01 & 02     75230
# 1158       Dallas ISD       Ambassador House Condos     75230
#
#      Property Sub Type  Property Type    Price Group Close Year Close Month
# 1151         RES-Condo    Residential        < $100k       2019           6
# 1154         RES-Condo    Residential        < $100k       2019           6
# 1156         RES-Condo    Residential  $100k - $250k       2019           7
# 1157         RES-Condo    Residential  $100k - $250k       2019           7
# 1158         RES-Condo    Residential  $100k - $250k       2019           7
#
# [5 rows x 30 columns]

# %%
#plot top 5 performing zip code average sale price using seaborn

Top_Zip_df = sold_mls_df.loc[sold_mls_df["Zip Code"].isin([75025,75225,75201,75209, 75230])]

df = Top_Zip_df[["City", "Zip Code", "Close Year", "Close Month", "Close Price" ]]

order = df["Close Year"]

df_wide = df.pivot_table(
    index="Close Year", 
    columns='Zip Code', 
    values='Close Price',
    aggfunc = "mean")

df_wide = df_wide.reindex(order, axis=0)

plt.figure(figsize=(15,12))
ax = sns.lineplot(data=df_wide)

#formatting
plt.title ("Top 5 Zip Codes \n Average Sale Price by Year", size = 24)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick) 
plt.ylabel("Average Sale Price")
plt.savefig("TopZip_AverageSalePrice.png")
plt.show()

# %%
#plot top 5 performing zip code sale counts using seaborn

Top_Zip_df = sold_mls_df.loc[sold_mls_df["Zip Code"].isin([75025,75225,75201,75209, 75230])]

df = Top_Zip_df[["City", "Zip Code", "Close Year", "Close Month", "Close Price" ]]

order = df["Close Year"]

df_wide = df.pivot_table(
    index="Close Year", 
    columns='Zip Code', 
    values='Close Price',
    aggfunc = "count")

df_wide = df_wide.reindex(order, axis=0)

plt.figure(figsize=(15,12))
ax = sns.lineplot(data=df_wide)
plt.title ("Top 5 Zip Codes \n Sale Count by Year", size = 24)
plt.ylabel("Sale Count")
plt.show()
plt.savefig("TopZip_SaleCount.png")

# %%
#plot bottom 5 performing zip code average sale price

Bottom_Zip_df = sold_mls_df.loc[sold_mls_df["Zip Code"].isin([75149,75180,75241,75217,75216])]

df = Bottom_Zip_df[["City", "Zip Code", "Close Year", "Close Month", "Close Price" ]]

order = df["Close Year"]

df_wide = df.pivot_table(
    index="Close Year", 
    columns='Zip Code', 
    values='Close Price',
    aggfunc = "mean")

df_wide = df_wide.reindex(order, axis=0)

plt.figure(figsize=(15,12))
plt.title ("Bottom 5 Zip Codes \n Average Sale Price by Year", size = 24)
ax = sns.lineplot(data=df_wide)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
plt.ylabel("Average Sale Price")
plt.show()
plt.savefig("BottomZip_AverageSalePrice.png")

# %%
#plot bottom 5 performing zip code sale counts

Bottom_Zip_df = sold_mls_df.loc[sold_mls_df["Zip Code"].isin([75149,75180,75241,75217,75216])]

df = Bottom_Zip_df[["City", "Zip Code", "Close Year", "Close Month", "Close Price"]]

order = df["Close Year"]

df_wide = df.pivot_table(
    index="Close Year", 
    columns='Zip Code', 
    values='Close Price',
    aggfunc = "count")

df_wide = df_wide.reindex(order, axis=0)

plt.figure(figsize=(15,12))
sns.lineplot(data=df_wide)
plt.title ("Bottom 5 Zip Codes \n Sale Count by Year", size = 24)
plt.ylabel("Sale Count")
plt.savefig("BottomZip_SaleCount.png")
plt.show()

# %% [markdown]
# # Calculating Year over Year Appreciation

# %%
AveragePricePerYear = sold_mls_df.groupby(["Close Year"])["Close Price"].mean()

AveragePricePerYear = AveragePricePerYear.to_frame().reset_index()

AveragePricePerYear.rename(columns = {"Close Year":"Close Year", "Close Price": "Average Close Price"}, inplace=True)

AveragePricePerYear['Percent Change'] = AveragePricePerYear['Average Close Price'].pct_change() *100
#AveragePricePerYear["Percent Change"] = AveragePricePerYear["Percent Change"]

AveragePricePerYear.head()
# Out:
#    Close Year  Average Close Price  Percent Change
# 0        2016        308892.754659             NaN
# 1        2017        337910.763529        9.394202
# 2        2018        353531.280320        4.622675
# 3        2019        355835.642197        0.651813
# 4        2020        388557.820465        9.195869

# %%
#plot percent change by close year

plt.figure(figsize=(15,12))
#plt.xticks(rotation=45)
#sns.barplot("Close Month", "Percent Change", data=AveragePricePerYear, ci=False)
ax1 = sns.barplot(x="Close Year", y="Percent Change", data=AveragePricePerYear,  ci=False)

label_format = '{:,.2f}%'
ticks_loc = ax1.get_yticks().tolist()
ax1.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
ax1.set_yticklabels([label_format.format(x) for x in ticks_loc])


ax1.set_xticks(ax1.get_xticks())

plt.show()
plt.savefig("PercentChange_YoY.png")

# %%
ZipAveragePricePerYear = sold_mls_df.groupby(["Close Year", "Zip Code"])["Close Price"].mean()

ZipAveragePricePerYear = ZipAveragePricePerYear.to_frame().reset_index()

ZipAveragePricePerYear.rename(columns = {"Close Year":"Close Year", "Close Price": "Average Close Price"}, inplace=True)

ZipAveragePricePerYear['Percent Change'] = ZipAveragePricePerYear['Average Close Price'].pct_change()
#AveragePricePerYear["Percent Change"] = AveragePricePerYear["Percent Change"]

Top_Zip_df = ZipAveragePricePerYear.loc[ZipAveragePricePerYear["Zip Code"].isin([75225,75205,75252, 75214, 75218, 75229])]

plt.figure(figsize=(15,12))
plt.xticks(rotation=45)
#sns.barplot("Close Month", "Percent Change", data=AveragePricePerYear, ci=False)
ax = sns.barplot(x="Close Year", y="Percent Change", data=Top_Zip_df, hue="Zip Code" ,ci=False)
y_value=['{:,.2f}'.format(x) + '%' for x in ax.get_yticks()]
ax.set_yticklabels(y_value)
plt.title ("Percent Change in Average Sales Price by Year", size = 24)
plt.show()
# Out:
# <ipython-input-31-5d6c180d3de2>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(y_value)

# %%
Top_Zip_df.head()
# Out:
#     Close Year  Zip Code  Average Close Price  Percent Change
# 46        2016     75205         1.331607e+06        2.413326
# 53        2016     75214         5.720581e+05        3.242962
# 57        2016     75218         3.825241e+05        2.887877
# 62        2016     75225         1.173235e+06        5.757584
# 66        2016     75229         5.316017e+05        1.678019
